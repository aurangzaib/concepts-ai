# %% [markdown]
# ---
# # **Preparation**
# ---

# %%
# System Libraries
import importlib

# User Libraries
import modules.Chapter_01 as Chapter_01

# Reload Libraries
importlib.reload(Chapter_01)
# Out:
# <module 'modules.Chapter_01' from '/Users/siddiqui/Projects/concepts/concepts-ai/modules/Chapter_01.py'>

# %% [markdown]
# ---
# # **Dataset**
# ---

# %% [markdown]
# **Description**
#
# | Topic | Detail |
# | --- | --- |
# | Dataset | MNIST: Hand written letters |
# | Sample | 28x28 image pixels (range: 0-255)  |
# | Label |  0-9 number |
# | Last Activation | Softmax |
# | Loss | CategoricalCrossentropy |
# | Optimizer | RMSprop |
# | Metric | CategoricalAccuracy |

# %%
(x_train, y_train), (
    x_test,
    y_test,
) = Chapter_01.dataset()
# Out:
# Data type:  uint8
# Samples:  (60000, 28, 28)
# Dim:  3
# 7

# %% [markdown]
# ---
# # **Training**
# ---

# %%
epoch = 5
model, history = Chapter_01.train(x_train, y_train, epoch)

# %% [markdown]
# ---
# # **Exploration**
# ---

# %%
Chapter_01.explore(history)
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy'])
# Training Loss:  0.05343058705329895
# Training Accuracy:  0.9853333234786987

# %% [markdown]
# ---
# # **Evaluate**
# ---

# %%
Chapter_01.evaluate(x_test, y_test, model)
# Out:
# Test Loss:  0.10256709158420563
# Test Acc:  0.9764000177383423

# %% [markdown]
# ---
# # **Prediction**
# ---

# %%
Chapter_01.predict(x_test, y_test, model)
# Out:
# Ground:  7
# Prediction:  7
# Confidence:  1.0
#
# Ground:  2
# Prediction:  2
# Confidence:  1.0
#
# Ground:  1
# Prediction:  1
# Confidence:  0.9999894
#
# Ground:  0
# Prediction:  0
# Confidence:  0.9999372
#
# Ground:  4
# Prediction:  4
# Confidence:  0.999546

# %% [markdown]
# ---
